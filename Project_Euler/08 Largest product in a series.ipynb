# %% [markdown]
# # Largest product in a series

# %%
n="""..."""

# %%
n
# Out:
# '...'

# %%
len(n)
# Out:
# 1000

# %%
l=[]
for i in range(len(n)-4):
    pro = 1
    for j in range(4):
        pro *= int(n[i+j])
    l.append(pro)

# %%
l
# Out:
# [126,
#  126,
#  42,
#  294,
#  294,
#  210,
#  630,
#  90,
#  45,
#  27,
#  0,
#  0,
#  0,
#  0,
#  432,
#  72,
#  324,
#  162,
#  36,
#  180,
#  20,
#  10,
#  45,
#  54,
#  378,
#  1512,
#  672,
#  224,
#  192,
#  240,
#  420,
#  840,
#  980,
#  784,
#  224,
#  168,
#  120,
#  150,
#  225,
#  300,
#  540,
#  108,
#  324,
#  324,
#  324,
#  972,
#  432,
#  972,
#  648,
#  1944,
#  3888,
#  1296,
#  1080,
#  240,
#  0,
#  0,
#  0,
#  0,
#  42,
#  98,
#  392,
#  980,
#  0,
#  0,
#  0,
#  0,
#  216,
#  72,
#  72,
#  324,
#  270,
#  945,
#  2520,
#  840,
#  168,
#  192,
#  0,
#  0,
#  0,
#  0,
#  432,
#  1728,
#  2304,
#  0,
#  0,
#  0,
#  0,
#  432,
#  1728,
#  1512,
#  2016,
#  1792,
#  2240,
#  320,
#  320,
#  160,
#  96,
#  768,
#  480,
#  960,
#  1920,
#  240,
#  240,
#  180,
#  0,
#  0,
#  0,
#  0,
#  504,
#  72,
#  18,
#  18,
#  72,
#  648,
#  1296,
#  1296,
#  1620,
#  720,
#  900,
#  900,
#  900,
#  0,
#  0,
#  0,
#  0,
#  147,
#  1323,
#  945,
#  2520,
#  1080,
#  360,
#  72,
# ...

# %%
max(l)
# Out:
# 5832

# %%
l=[]
for i in range(len(n)-13):
    pro = 1
    for j in range(13):
        pro *= int(n[i+j])
    l.append(pro)
    
max(l)
# Out:
# 23514624000
