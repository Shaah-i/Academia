# %%
import pandas as pd

# %%
df= pd.read_csv('metor_data.csv')
df
# Out:
#           name     id nametype               recclass      mass    year
# 0       Aachen      1    Valid                     L5      21.0  1880.0  \
# 1       Aarhus      2    Valid                     H6     720.0  1951.0
# 2         Abee      6    Valid                    EH4  107000.0  1952.0
# 3     Acapulco     10    Valid            Acapulcoite    1914.0  1976.0
# 4      Achiras    370    Valid                     L6     780.0  1902.0
# ..         ...    ...      ...                    ...       ...     ...
# 995   Tirupati  24009    Valid                     H6     230.0  1934.0
# 996    Tissint  54823    Valid  Martian (shergottite)    7000.0  2011.0
# 997      Tjabe  24011    Valid                     H6   20000.0  1869.0
# 998   Tjerebon  24012    Valid                     L5   16500.0  1922.0
# 999  Tomakovka  24019    Valid                    LL6     600.0  1905.0
#
#        reclat    reclong      point_coordinates
# 0    50.77500    6.08333      [6.08333, 50.775]
# ...

# %% [markdown]
# ### 1. Earth meteorites that fell before the year 2000

# %%
df[df['year']<2000]
# Out:
#           name     id nametype     recclass      mass    year    reclat
# 0       Aachen      1    Valid           L5      21.0  1880.0  50.77500  \
# 1       Aarhus      2    Valid           H6     720.0  1951.0  56.18333
# 2         Abee      6    Valid          EH4  107000.0  1952.0  54.21667
# 3     Acapulco     10    Valid  Acapulcoite    1914.0  1976.0  16.88333
# 4      Achiras    370    Valid           L6     780.0  1902.0 -33.16667
# ..         ...    ...      ...          ...       ...     ...       ...
# 994   Timochin  24004    Valid           H5   65500.0  1807.0  54.50000
# 995   Tirupati  24009    Valid           H6     230.0  1934.0  13.63333
# 997      Tjabe  24011    Valid           H6   20000.0  1869.0  -7.08333
# 998   Tjerebon  24012    Valid           L5   16500.0  1922.0  -6.66667
# 999  Tomakovka  24019    Valid          LL6     600.0  1905.0  47.85000
#
#        reclong      point_coordinates
# 0      6.08333      [6.08333, 50.775]
# ...

# %% [markdown]
# ### 2. Earth meteorites co-ordinates who fell before the year 1970

# %%
df[df['year']<1970].point_coordinates
# Out:
# 0          [6.08333, 50.775]
# 1       [10.23333, 56.18333]
# 2           [-113, 54.21667]
# 4        [-64.95, -33.16667]
# 5               [71.8, 32.1]
#                ...
# 994             [35.2, 54.5]
# 995     [79.41667, 13.63333]
# 997    [111.53333, -7.08333]
# 998    [106.58333, -6.66667]
# 999        [34.76667, 47.85]
# Name: point_coordinates, Length: 763, dtype: object

# %% [markdown]
# ### 3. Earth meteorites whose mass was more than 10000kg, assuming that the mass of the earth meteorites was in kg

# %%
df[df['mass']>10000]
# Out:
#            name     id nametype   recclass      mass    year    reclat
# 2          Abee      6    Valid        EH4  107000.0  1952.0  54.21667  \
# 7          Agen    392    Valid         H5   30000.0  1814.0  44.21667
# 11          Aïr    424    Valid         L6   24000.0  1925.0  19.08333
# 16      Akyumak    433    Valid  Iron, IVA   50000.0  1981.0  39.91667
# 27   Alfianello    466    Valid         L6  228000.0  1883.0  45.26667
# ..          ...    ...      ...        ...       ...     ...       ...
# 991   Tieschitz  23989    Valid     H/L3.6   28000.0  1878.0  49.60000
# 992      Tilden  23998    Valid         L6   74800.0  1927.0  38.20000
# 994    Timochin  24004    Valid         H5   65500.0  1807.0  54.50000
# 997       Tjabe  24011    Valid         H6   20000.0  1869.0  -7.08333
# 998    Tjerebon  24012    Valid         L5   16500.0  1922.0  -6.66667
#
#        reclong      point_coordinates
# 2   -113.00000       [-113, 54.21667]
# ...
