# %% [markdown]
# ## 30-07-2022
#
# Pandas
#
# https://docs.google.com/spreadsheets/d/1z4EWsGxw0YBQ1-51xZDxYNlB3ngJzg4t/edit?usp=sharing&ouid=118282207943964605599&rtpof=true&sd=true
#
#
# https://docs.google.com/spreadsheets/d/1z2n8aeFF5GoohQ3KCZw8bKogezpO9l4k/edit?usp=sharing&ouid=118282207943964605599&rtpof=true&sd=true
#
# 1. Find out there avarage rating on weekly basis keep this in a mind that they take two days of leave
# 2. Total working days for each agents
# 3. Total query that you hvae taken
# 4. Total Feedback that you have received
# 5. An agent name who have average rating between 3.5 to 4
# 6. Agent name who have rating less than 3.5
# 7. Agent name who have rating more than 4.5
# 8. How many feedaback agents have received more than 4.5 average
# 9. Average weekly response time for each agent
# 10. Average weekely resolution time for each agents
# 11. List of all agents name
# 12. Percentage of chat on which they have received a feedback
# 13. Total contributation hour for each and every agents weekly basis
# 14. Total percentage of active hour for a month
#
# sunny.savita@ineuron.ai ,sudhanshu@ineuron.ai
#
# deadline of compeletion of this task is 12 AM IST today
#
# After that if you will submit your task i wont evaluate it at all , excuses will be given to new
# joiners.

# %%
import pandas as pd

# %%
login = pd.read_csv("G:\Study\ineuron\Live coding in lectures\Pandas\data fsds -20220726T060614Z-001\data fsds\Agent_Login_Report (4).xls - Agent Login Report.csv", skiprows= 2, index_col='SL No')
login
# Out:
#                     Agent       Date   Login Time  Logout Time   Duration
# SL No
# 1      Shivananda Sonwane  30-Jul-22  03:35:29 PM  05:39:39 PM   02:04:10
# 2          Khushboo Priya  30-Jul-22  03:06:59 PM  03:07:16 PM   00:00:17
# 3           Nandani Gupta  30-Jul-22  03:04:24 PM  05:31:07 PM   02:26:42
# 4         Hrisikesh Neogi  30-Jul-22  02:34:29 PM  03:19:35 PM   00:45:06
# 5                 Mukesh   30-Jul-22  02:03:15 PM  03:11:52 PM   01:08:36
# ...                   ...        ...          ...          ...        ...
# 996          Manjunatha A  20-Jul-22  09:03:51 AM  03:02:28 PM   05:58:37
# 997              Bharath   20-Jul-22  09:00:49 AM  03:01:32 PM   06:00:43
# 998        Khushboo Priya  20-Jul-22  08:59:20 AM  02:26:55 PM   05:27:34
# 999          Nishtha Jain  20-Jul-22  08:43:55 AM  02:00:33 PM   05:16:38
# 1000               Tarun   01-Jul-22  01:52:47 AM  12:01:07 PM  514:08:20
#
# [1000 rows x 5 columns]

# %%
performance = pd.read_csv("G:\Study\ineuron\Live coding in lectures\Pandas\data fsds -20220726T060614Z-001\data fsds\AgentPerformance (1).xlsx - Agent Performance Report.csv", skiprows=1, index_col='SL No')
performance
# Out:
#              Date          Agent Name  Total Chats Average Response Time  \
# SL No
# 1      2022-07-30        Prerna Singh           11              00:00:38
# 2      2022-07-30       Nandani Gupta           11              00:01:15
# 3      2022-07-30          Ameya Jain           14              00:00:30
# 4      2022-07-30       Mahesh Sarade           14              00:01:04
# 5      2022-07-30              Swati            14              00:01:11
# ...           ...                 ...          ...                   ...
# 2156   2022-07-01   Sowmiya Sivakumar            0              00:00:00
# 2157   2022-07-01             Nitin M            0              00:00:00
# 2158   2022-07-01              Vivek             0              00:00:00
# 2159   2022-07-01       Ayushi Mishra            0              00:00:00
# 2160   2022-07-01  Chaitra K Hiremath            0              00:00:00
#
#       Average Resolution Time  Average Rating  Total Feedback
# SL No
# ...

# %%
performance.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2160 entries, 1 to 2160
# Data columns (total 7 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Date                     2160 non-null   object
#  1   Agent Name               2160 non-null   object
#  2   Total Chats              2160 non-null   int64
#  3   Average Response Time    2160 non-null   object
#  4   Average Resolution Time  2160 non-null   object
#  5   Average Rating           2160 non-null   float64
#  6   Total Feedback           2160 non-null   int64
# dtypes: float64(1), int64(2), object(4)
# memory usage: 135.0+ KB

# %% [markdown]
# ### 1. Find out there avarage rating on weekly basis keep this in a mind that they take two days of leave

# %%
performance['Date']  = pd.to_datetime(performance['Date'])
performance.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2160 entries, 1 to 2160
# Data columns (total 7 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Date                     2160 non-null   datetime64[ns]
#  1   Agent Name               2160 non-null   object
#  2   Total Chats              2160 non-null   int64
#  3   Average Response Time    2160 non-null   object
#  4   Average Resolution Time  2160 non-null   object
#  5   Average Rating           2160 non-null   float64
#  6   Total Feedback           2160 non-null   int64
# dtypes: datetime64[ns](1), float64(1), int64(2), object(3)
# memory usage: 135.0+ KB

# %%
# Series.dt.weekofyear and Series.dt.week have been deprecated.
performance['Week'] = performance['Date'].dt.isocalendar().week
performance
# Out:
#             Date          Agent Name  Total Chats Average Response Time  \
# SL No
# 1     2022-07-30        Prerna Singh           11              00:00:38
# 2     2022-07-30       Nandani Gupta           11              00:01:15
# 3     2022-07-30          Ameya Jain           14              00:00:30
# 4     2022-07-30       Mahesh Sarade           14              00:01:04
# 5     2022-07-30              Swati            14              00:01:11
# ...          ...                 ...          ...                   ...
# 2156  2022-07-01   Sowmiya Sivakumar            0              00:00:00
# 2157  2022-07-01             Nitin M            0              00:00:00
# 2158  2022-07-01              Vivek             0              00:00:00
# 2159  2022-07-01       Ayushi Mishra            0              00:00:00
# 2160  2022-07-01  Chaitra K Hiremath            0              00:00:00
#
#       Average Resolution Time  Average Rating  Total Feedback  Week
# SL No
# ...

# %%
weekly_average_rating = pd.DataFrame(performance.groupby(['Agent Name','Week'])['Average Rating'].mean())
weekly_average_rating
# Out:
#                  Average Rating
# Agent Name Week
# Abhishek   26          0.000000
#            27          0.000000
#            28          0.000000
#            29          0.000000
#            30          0.000000
# ...                         ...
# Zeeshan    26          0.000000
#            27          1.307143
#            28          2.948571
#            29          3.180000
#            30          2.760000
#
# [350 rows x 1 columns]

# %% [markdown]
# ### 2 .Total working days for each agents

# %%
performance['Day'] = performance['Date'].dt.day
performance
# Out:
#             Date          Agent Name  Total Chats Average Response Time  \
# SL No
# 1     2022-07-30        Prerna Singh           11              00:00:38
# 2     2022-07-30       Nandani Gupta           11              00:01:15
# 3     2022-07-30          Ameya Jain           14              00:00:30
# 4     2022-07-30       Mahesh Sarade           14              00:01:04
# 5     2022-07-30              Swati            14              00:01:11
# ...          ...                 ...          ...                   ...
# 2156  2022-07-01   Sowmiya Sivakumar            0              00:00:00
# 2157  2022-07-01             Nitin M            0              00:00:00
# 2158  2022-07-01              Vivek             0              00:00:00
# 2159  2022-07-01       Ayushi Mishra            0              00:00:00
# 2160  2022-07-01  Chaitra K Hiremath            0              00:00:00
#
#       Average Resolution Time  Average Rating  Total Feedback  Week  Day
# SL No
# ...

# %%
working_days = pd.DataFrame(performance.groupby(['Agent Name'])['Day'].count())
working_days
# Out:
#                Day
# Agent Name
# Abhishek        30
# Aditya          30
# Aditya Shinde   30
# Aditya_iot      30
# Amersh          30
# ...            ...
# Uday Mishra     30
# Vasanth P       30
# Vivek           30
# Wasim           30
# Zeeshan         30
#
# [70 rows x 1 columns]

# %% [markdown]
# ### 3. Total query that you have taken.

# %%
Total_queries = pd.DataFrame(performance.groupby('Agent Name')['Total Chats'].sum())
Total_queries
# Out:
#                Total Chats
# Agent Name
# Abhishek                 0
# Aditya                   0
# Aditya Shinde          277
# Aditya_iot             231
# Amersh                   0
# ...                    ...
# Uday Mishra              0
# Vasanth P                0
# Vivek                   44
# Wasim                  433
# Zeeshan                542
#
# [70 rows x 1 columns]

# %% [markdown]
# ### 4. Total Feedback that you have received

# %%
Total_feedbacks = pd.DataFrame(performance.groupby('Agent Name')['Total Feedback'].sum())
Total_feedbacks
# Out:
#                Total Feedback
# Agent Name
# Abhishek                    0
# Aditya                      0
# Aditya Shinde             153
# Aditya_iot                131
# Amersh                      0
# ...                       ...
# Uday Mishra                 0
# Vasanth P                   0
# Vivek                      20
# Wasim                     284
# Zeeshan                   335
#
# [70 rows x 1 columns]

# %% [markdown]
# ### 5. An agent name who have average rating between 3.5 to 4

# %%
weekly_average_rating[((weekly_average_rating['Average Rating']>3.5) & (weekly_average_rating['Average Rating'] < 4))]
# Out:
#                           Average Rating
# Agent Name          Week
# Ayushi Mishra       30          3.845000
# Boktiar Ahmed Bappy 27          3.951429
#                     29          3.792857
# Harikrishnan Shaji  30          3.600000
# Jawala Prakash      30          3.948333
# Khushboo Priya      27          3.810000
#                     29          3.922857
# Madhulika G         27          3.784286
#                     28          3.672857
# Maitry              29          3.741429
# Manjunatha A        27          3.992857
# Muskan Garg         30          3.561667
# Prateek _iot        30          3.705000
# Prerna Singh        30          3.541667
# Sanjeev Kumar       30          3.793333
# Shivananda Sonwane  27          3.794286
#                     28          3.770000
# Wasim               30          3.581667

# %%
avg_rating = pd.DataFrame(performance.groupby(['Agent Name'])['Average Rating'].mean())
avg_rating[((avg_rating['Average Rating'] > 3.5) & (avg_rating['Average Rating'] < 4))]
# Out:
#                      Average Rating
# Agent Name
# Boktiar Ahmed Bappy        3.568000
# Ishawant Kumar             3.543333
# Khushboo Priya             3.703667
# Manjunatha A               3.594667

# %% [markdown]
# ### 6. Agent name who have rating lesss than 3.5

# %%
weekly_average_rating[((weekly_average_rating['Average Rating'] < 3.5))]
# Out:
#                  Average Rating
# Agent Name Week
# Abhishek   26          0.000000
#            27          0.000000
#            28          0.000000
#            29          0.000000
#            30          0.000000
# ...                         ...
# Zeeshan    26          0.000000
#            27          1.307143
#            28          2.948571
#            29          3.180000
#            30          2.760000
#
# [314 rows x 1 columns]

# %%
avg_rating[(avg_rating['Average Rating'] < 3.5)]
# Out:
#                Average Rating
# Agent Name
# Abhishek             0.000000
# Aditya               0.000000
# Aditya Shinde        1.800333
# Aditya_iot           2.345333
# Amersh               0.000000
# ...                       ...
# Uday Mishra          0.000000
# Vasanth P            0.000000
# Vivek                0.500667
# Wasim                2.400000
# Zeeshan              2.287000
#
# [65 rows x 1 columns]

# %% [markdown]
# ### 7. Agent name who have rating more than 4.5

# %%
weekly_average_rating[(weekly_average_rating['Average Rating'] > 4.5)]
# Out:
#                           Average Rating
# Agent Name          Week
# Boktiar Ahmed Bappy 26          4.720000
# Deepranjan Gupta    30          4.615000
# Ishawant Kumar      30          4.706667
# Jawala Prakash      26          4.523333
# Madhulika G         26          4.833333
# Manjunatha A        26          4.563333
# Nishtha Jain        27          4.657143
# Shivananda Sonwane  26          4.753333
#                     30          4.751667

# %%
avg_rating[(avg_rating['Average Rating'] > 4.5)]
# Out:
# Empty DataFrame
# Columns: [Average Rating]
# Index: []

# %% [markdown]
# ### 8. How many feedaback agents have received more than 4.5 average

# %%
avg_feedback = pd.DataFrame(performance.groupby('Agent Name')['Total Feedback'].mean())
avg_feedback[avg_feedback['Total Feedback'] > 4.5]
# Out:
#                         Total Feedback
# Agent Name
# Aditya Shinde                 5.100000
# Ameya Jain                    7.600000
# Aravind                       7.766667
# Ayushi Mishra                10.966667
# Bharath                       8.233333
# Boktiar Ahmed Bappy          10.366667
# Deepranjan Gupta             10.400000
# Harikrishnan Shaji            7.700000
# Hrisikesh Neogi              12.233333
# Ishawant Kumar                6.733333
# Jawala Prakash                8.333333
# Jaydeep Dixit                10.166667
# Khushboo Priya                9.633333
# Madhulika G                   9.366667
# Mahesh Sarade                 7.200000
# Maitry                       11.566667
# Manjunatha A                  8.466667
# Mithun S                     12.133333
# Nandani Gupta                10.266667
# Nishtha Jain                  8.566667
# Prabir Kumar Satapathy        7.400000
# Prerna Singh                  7.833333
# Saikumarreddy N               9.666667
# ...

# %% [markdown]
# ### 9. Average weekly response time for each agent

# %%
performance['Avg_Resp_sec'] = pd.to_timedelta(performance['Average Response Time']).dt.total_seconds()
performance
# Out:
#             Date          Agent Name  Total Chats Average Response Time  \
# SL No
# 1     2022-07-30        Prerna Singh           11              00:00:38
# 2     2022-07-30       Nandani Gupta           11              00:01:15
# 3     2022-07-30          Ameya Jain           14              00:00:30
# 4     2022-07-30       Mahesh Sarade           14              00:01:04
# 5     2022-07-30              Swati            14              00:01:11
# ...          ...                 ...          ...                   ...
# 2156  2022-07-01   Sowmiya Sivakumar            0              00:00:00
# 2157  2022-07-01             Nitin M            0              00:00:00
# 2158  2022-07-01              Vivek             0              00:00:00
# 2159  2022-07-01       Ayushi Mishra            0              00:00:00
# 2160  2022-07-01  Chaitra K Hiremath            0              00:00:00
#
#       Average Resolution Time  Average Rating  Total Feedback  Week  Day  \
# SL No
# ...

# %%
Average_weekly_response = pd.DataFrame(performance.groupby(['Agent Name','Week'])['Avg_Resp_sec'].mean())
Average_weekly_response
# Out:
#                  Avg_Resp_sec
# Agent Name Week
# Abhishek   26        0.000000
#            27        0.000000
#            28        0.000000
#            29        0.000000
#            30        0.000000
# ...                       ...
# Zeeshan    26        0.000000
#            27       23.571429
#            28      123.428571
#            29       62.857143
#            30       63.833333
#
# [350 rows x 1 columns]

# %% [markdown]
# ### 10. Average weekely resolution time for each agents

# %%
performance['Avg_Resol_sec'] = pd.to_timedelta(performance['Average Resolution Time']).dt.total_seconds()
performance
# Out:
#             Date          Agent Name  Total Chats Average Response Time  \
# SL No
# 1     2022-07-30        Prerna Singh           11              00:00:38
# 2     2022-07-30       Nandani Gupta           11              00:01:15
# 3     2022-07-30          Ameya Jain           14              00:00:30
# 4     2022-07-30       Mahesh Sarade           14              00:01:04
# 5     2022-07-30              Swati            14              00:01:11
# ...          ...                 ...          ...                   ...
# 2156  2022-07-01   Sowmiya Sivakumar            0              00:00:00
# 2157  2022-07-01             Nitin M            0              00:00:00
# 2158  2022-07-01              Vivek             0              00:00:00
# 2159  2022-07-01       Ayushi Mishra            0              00:00:00
# 2160  2022-07-01  Chaitra K Hiremath            0              00:00:00
#
#       Average Resolution Time  Average Rating  Total Feedback  Week  Day  \
# SL No
# ...

# %%
Average_weekly_resolution = pd.DataFrame(performance.groupby(['Agent Name','Week'])['Avg_Resol_sec'].mean())
Average_weekly_resolution
# Out:
#                  Avg_Resol_sec
# Agent Name Week
# Abhishek   26         0.000000
#            27         0.000000
#            28         0.000000
#            29         0.000000
#            30         0.000000
# ...                        ...
# Zeeshan    26         0.000000
#            27       323.000000
#            28       984.285714
#            29       794.285714
#            30       773.500000
#
# [350 rows x 1 columns]

# %% [markdown]
# ### 11. List of all agents name

# %%
performance['Agent Name'].value_counts()
# Out:
# Rishav Dash       60
# Ashish            60
# Sandipan Saha     30
# Anurag Tiwari     30
# Zeeshan           30
#                   ..
# Saurabh Shukla    30
# Wasim             30
# Samprit           30
# Maitry            30
# Jawala Prakash    30
# Name: Agent Name, Length: 70, dtype: int64

# %% [markdown]
# ### 12. Percentage of chat on which they have received a feedback

# %%
performance['Percent_feedback_per_chat'] = (performance['Total Feedback']/performance['Total Chats'])*100
performance
# Out:
#             Date          Agent Name  Total Chats Average Response Time  \
# SL No
# 1     2022-07-30        Prerna Singh           11              00:00:38
# 2     2022-07-30       Nandani Gupta           11              00:01:15
# 3     2022-07-30          Ameya Jain           14              00:00:30
# 4     2022-07-30       Mahesh Sarade           14              00:01:04
# 5     2022-07-30              Swati            14              00:01:11
# ...          ...                 ...          ...                   ...
# 2156  2022-07-01   Sowmiya Sivakumar            0              00:00:00
# 2157  2022-07-01             Nitin M            0              00:00:00
# 2158  2022-07-01              Vivek             0              00:00:00
# 2159  2022-07-01       Ayushi Mishra            0              00:00:00
# 2160  2022-07-01  Chaitra K Hiremath            0              00:00:00
#
#       Average Resolution Time  Average Rating  Total Feedback  Week  Day  \
# SL No
# ...

# %% [markdown]
# ### 13. Total contributation hour for each and every agents weekly basis

# %%
login.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1000 entries, 1 to 1000
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Agent        1000 non-null   object
#  1   Date         1000 non-null   object
#  2   Login Time   1000 non-null   object
#  3   Logout Time  1000 non-null   object
#  4   Duration     1000 non-null   object
# dtypes: object(5)
# memory usage: 46.9+ KB

# %%
login['Date']  = pd.to_datetime(login['Date'])
login.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1000 entries, 1 to 1000
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Agent        1000 non-null   object
#  1   Date         1000 non-null   datetime64[ns]
#  2   Login Time   1000 non-null   object
#  3   Logout Time  1000 non-null   object
#  4   Duration     1000 non-null   object
# dtypes: datetime64[ns](1), object(4)
# memory usage: 46.9+ KB

# %%
login['Week'] = login['Date'].dt.isocalendar().week
login
# Out:
#                     Agent       Date   Login Time  Logout Time   Duration  \
# SL No
# 1      Shivananda Sonwane 2022-07-30  03:35:29 PM  05:39:39 PM   02:04:10
# 2          Khushboo Priya 2022-07-30  03:06:59 PM  03:07:16 PM   00:00:17
# 3           Nandani Gupta 2022-07-30  03:04:24 PM  05:31:07 PM   02:26:42
# 4         Hrisikesh Neogi 2022-07-30  02:34:29 PM  03:19:35 PM   00:45:06
# 5                 Mukesh  2022-07-30  02:03:15 PM  03:11:52 PM   01:08:36
# ...                   ...        ...          ...          ...        ...
# 996          Manjunatha A 2022-07-20  09:03:51 AM  03:02:28 PM   05:58:37
# 997              Bharath  2022-07-20  09:00:49 AM  03:01:32 PM   06:00:43
# 998        Khushboo Priya 2022-07-20  08:59:20 AM  02:26:55 PM   05:27:34
# 999          Nishtha Jain 2022-07-20  08:43:55 AM  02:00:33 PM   05:16:38
# 1000               Tarun  2022-07-01  01:52:47 AM  12:01:07 PM  514:08:20
#
#        Week
# SL No
# 1        30
# 2        30
# 3        30
# ...

# %%
login['Duration_hrs'] = pd.to_timedelta(login['Duration']).dt.total_seconds()//3600
login
# Out:
#                     Agent       Date   Login Time  Logout Time   Duration  \
# SL No
# 1      Shivananda Sonwane 2022-07-30  03:35:29 PM  05:39:39 PM   02:04:10
# 2          Khushboo Priya 2022-07-30  03:06:59 PM  03:07:16 PM   00:00:17
# 3           Nandani Gupta 2022-07-30  03:04:24 PM  05:31:07 PM   02:26:42
# 4         Hrisikesh Neogi 2022-07-30  02:34:29 PM  03:19:35 PM   00:45:06
# 5                 Mukesh  2022-07-30  02:03:15 PM  03:11:52 PM   01:08:36
# ...                   ...        ...          ...          ...        ...
# 996          Manjunatha A 2022-07-20  09:03:51 AM  03:02:28 PM   05:58:37
# 997              Bharath  2022-07-20  09:00:49 AM  03:01:32 PM   06:00:43
# 998        Khushboo Priya 2022-07-20  08:59:20 AM  02:26:55 PM   05:27:34
# 999          Nishtha Jain 2022-07-20  08:43:55 AM  02:00:33 PM   05:16:38
# 1000               Tarun  2022-07-01  01:52:47 AM  12:01:07 PM  514:08:20
#
#        Week  Duration_hrs
# SL No
# 1        30           2.0
# ...

# %%
weekly_contri_hr = pd.DataFrame(login.groupby(['Agent','Week'])['Duration_hrs'].sum())
weekly_contri_hr
# Out:
#                     Duration_hrs
# Agent         Week
# Aditya Shinde 30             0.0
# Aditya_iot    29             5.0
#               30             7.0
# Amersh        30             2.0
# Ameya Jain    29            21.0
# ...                          ...
# Tarun         26           514.0
# Wasim         29            18.0
#               30            25.0
# Zeeshan       29            23.0
#               30            24.0
#
# [89 rows x 1 columns]

# %% [markdown]
# ### 14. Total percentage of active hour for a month

# %%
login['Month'] = login['Date'].dt.month
login
# Out:
#                     Agent       Date   Login Time  Logout Time   Duration  \
# SL No
# 1      Shivananda Sonwane 2022-07-30  03:35:29 PM  05:39:39 PM   02:04:10
# 2          Khushboo Priya 2022-07-30  03:06:59 PM  03:07:16 PM   00:00:17
# 3           Nandani Gupta 2022-07-30  03:04:24 PM  05:31:07 PM   02:26:42
# 4         Hrisikesh Neogi 2022-07-30  02:34:29 PM  03:19:35 PM   00:45:06
# 5                 Mukesh  2022-07-30  02:03:15 PM  03:11:52 PM   01:08:36
# ...                   ...        ...          ...          ...        ...
# 996          Manjunatha A 2022-07-20  09:03:51 AM  03:02:28 PM   05:58:37
# 997              Bharath  2022-07-20  09:00:49 AM  03:01:32 PM   06:00:43
# 998        Khushboo Priya 2022-07-20  08:59:20 AM  02:26:55 PM   05:27:34
# 999          Nishtha Jain 2022-07-20  08:43:55 AM  02:00:33 PM   05:16:38
# 1000               Tarun  2022-07-01  01:52:47 AM  12:01:07 PM  514:08:20
#
#        Week  Duration_hrs  Month
# SL No
# ...

# %%
login['Month'].value_counts()
# their is only one month in consideration and it is July
# July has 31 days of which 21 were working days
# Considering agents worked for 8hrs daily
# 8*21 = 168 hrs for July month
# Out:
# 7    1000
# Name: Month, dtype: int64

# %%
percent_active_hrs_monthly = pd.DataFrame(login.groupby(['Agent'])['Duration_hrs'].sum()/(8*21))*100
percent_active_hrs_monthly
# Out:
#                         Duration_hrs
# Agent
# Aditya Shinde               0.000000
# Aditya_iot                  7.142857
# Amersh                      1.190476
# Ameya Jain                 22.023810
# Ankitjha                    1.190476
# Anurag Tiwari               0.000000
# Aravind                    13.690476
# Ayushi Mishra              18.452381
# Bharath                    26.785714
# Boktiar Ahmed Bappy        17.857143
# Chaitra K Hiremath         18.452381
# Deepranjan Gupta           52.976190
# Dibyanshu                  12.500000
# Harikrishnan Shaji         26.190476
# Hrisikesh Neogi            23.214286
# Hyder Abbas                 0.000000
# Ineuron Intelligence        0.595238
# Ishawant Kumar             25.000000
# Jawala Prakash             24.404762
# Jaydeep Dixit              33.333333
# Khushboo Priya             22.023810
# Madhulika G                23.809524
# Mahesh Sarade              19.642857
# Maitry                     17.857143
# ...
